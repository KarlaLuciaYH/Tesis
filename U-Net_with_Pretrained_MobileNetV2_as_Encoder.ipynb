# %% [markdown]
# # **U-Net con encoder (MobileNetV2)**
#
# **Autora: Karla Yacolca**
#
# **Primer bloque del sistema de Clasificación por Atipia Nuclear**
#
# Esta primera segmentación se hizo a partir de 43 imágenes de las 162 de BreCaHAD de 1360x1024 , se aplicó normalización y data augmentation para tener un total de 258 imágenes totales de 1024x1024 las que se dividieron en:
# Training data:  208
# Validation data:  25
# Testing data:  25
# Con batch=1 y 50 epochs
#
#
# Referencia: https://github.com/nikhilroxtomar/Unet-with-Pretrained-Encoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/PUCP :)/9no ciclo MI/TESIS 1y2_Karla/Avances Tesis 2/Segmentación - Códigos/Unet Keras/Unet_with_encoder/Unet_Pretrain_encoder_final1
# Out:
# /content/drive/My Drive/PUCP :)/9no ciclo MI/TESIS 1y2_Karla/Avances Tesis 2/Segmentación - Códigos/Unet Keras/Unet_with_encoder/Unet_Pretrain_encoder_final1

# %%
# %ls
# Out:
# BreCaHAD/             Normalizacion.py
# Data/                 U-Net_with_Pretrained_MobileNetV2_as_Encoder.ipynb
# data_augmentation.py

# %% [markdown]
# # Normalización del color

# %% [markdown]
# ESTE FUNCIONA, PROBAR QUITANDO LO DE PIP INSTALL, lei q pueede que PIL malogre las imagenes TIFF

# %%
#!pip show pillow

# %%
#!pip install Pillow==4.0.0
#!pip install PIL
#!pip install image
#import PIL.image    #estaba descomentado
import os, sys
from PIL import Image

#Creacion de la nueva carpeta con las imagenes normalizadas: images_norm
os.mkdir('/content/drive/My Drive/PUCP :)/9no ciclo MI/TESIS 1y2_Karla/Avances Tesis 2/Segmentación - Códigos/Unet Keras/Unet_with_encoder/Unet_Pretrain_encoder_final1/BreCaHAD/images_norm')
outfile= "/content/drive/My Drive/PUCP :)/9no ciclo MI/TESIS 1y2_Karla/Avances Tesis 2/Segmentación - Códigos/Unet Keras/Unet_with_encoder/Unet_Pretrain_encoder_final1/BreCaHAD/images_norm"

# Directorio de donde se toman las imagenes originales
imagenes= "/content/drive/My Drive/PUCP :)/9no ciclo MI/TESIS 1y2_Karla/Avances Tesis 2/Segmentación - Códigos/Unet Keras/Unet_with_encoder/Unet_Pretrain_encoder_final1/BreCaHAD/images_original"


#Aplicando normalizacion y guardando en carpeta imagen_norm
# %run -i Normalizacion.py
a=0
for infile in os.listdir(imagenes):
#for infile in os.listdir("./"): Con esto solo funciona si 1ero me pongo en la carpeta imagenes
    print( "file : " + infile)
    a=a+1
    im = Image.open(os.path.join(imagenes,infile)) #en open va todo el directorio por eso "join"
    #im.show()
    #outfile = infile[:-3] + "tif"
    [Inorm, H, E] = normalizeStaining(im)
    Image.fromarray(Inorm).save(os.path.join(outfile,infile)) #se guarda en ptro directorio con el mismo nombre infile
    #Inorm.save(outfile,"tif")
    #print( "file : " + outfile)
print("Imagenes procesadas : " + a)

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# Se hacen 5: CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Se guardó con numeración 1.tif, 2.tif ......
# Las nuevas imágenes están el la carpeta Data

# %%
# %run -i data_augmentation.py    #corregir lo ultimo en normalizacion.py para que cuente lo del directorio de data y no salga
                                 #Augmented Images: 0 - Augmented Masks: 0
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]
# Original Images: 43 - Original Masks: 43
# 100%|██████████| 43/43 [00:54<00:00,  1.26s/it]
# Augmented Images: 0 - Augmented Masks: 0

# %% [markdown]
# # **Red**

# %% [markdown]
# ## Importing Libraries and Functions

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K

# %%
print("TensorFlow Version: ", tf.__version__)
# Out:
# TensorFlow Version:  2.3.0

# %% [markdown]
# Seeding

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Hyperparameters

# %%
IMAGE_SIZE = 1024 #256
EPOCHS = 50
BATCH = 1
LR = 1e-4

PATH = "Data/"  #Ya estan normalizadas y segmentadas

# %% [markdown]
# ## Dataset
# You can download the dataset from <a href="https://polyp.grand-challenge.org/CVCClinicDB/">here</a> or from directly from the <a href="https://www.dropbox.com/s/p5qe9eotetjnbmq/CVC-ClinicDB.rar?dl=0">Dropbox</a>.
#
# <br/>
# Spliting the data into training, validation and testing with 80:10:10 ratio.

# %%
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))

    total_size = len(images)
    valid_size = int(split * total_size)
    test_size = int(split * total_size)

    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %% [markdown]
# Reading the images and masks

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %% [markdown]
# Building the tf.data pipeline for training, validation and testing dataset.

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(PATH)

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
print("Testing data: ", len(test_x))
# Out:
# Training data:  208
# Validation data:  25
# Testing data:  25

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 1.4)

# %% [markdown]
# ## Model

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)
    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    
    f = [16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    return model

# %%
model = model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 1025, 1025, 3 0           input_image[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 512, 512, 16) 432         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 512, 512, 16) 64          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 512, 512, 16) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 512, 512, 16) 144         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 512, 512, 16) 64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 512, 512, 16) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 512, 512, 8)  128         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 512, 512, 8)  32          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 512, 512, 48) 384         expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 512, 512, 48) 192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 512, 512, 48) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 513, 513, 48) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 256, 256, 48) 432         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 256, 256, 48) 192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 256, 256, 48) 0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 256, 256, 8)  384         block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 256, 256, 8)  32          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 256, 256, 48) 384         block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 256, 256, 48) 192         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 256, 256, 48) 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 256, 256, 48) 432         block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 256, 256, 48) 192         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 256, 256, 48) 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 256, 256, 8)  384         block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 256, 256, 8)  32          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 256, 256, 8)  0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 256, 256, 48) 384         block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 256, 256, 48) 192         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 256, 256, 48) 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 257, 257, 48) 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 128, 128, 48) 432         block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 128, 128, 48) 192         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 128, 128, 48) 0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 128, 128, 16) 768         block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 128, 128, 16) 64          block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 128, 128, 96) 1536        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 128, 128, 96) 384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 128, 128, 96) 0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 128, 128, 96) 864         block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 128, 128, 96) 384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 128, 128, 96) 0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 128, 128, 16) 1536        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 128, 128, 16) 64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 128, 128, 16) 0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 128, 128, 96) 1536        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 128, 128, 96) 384         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 128, 128, 96) 0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 128, 128, 96) 864         block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 128, 128, 96) 384         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 128, 128, 96) 0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 128, 128, 16) 1536        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 128, 128, 16) 64          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 128, 128, 16) 0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 128, 128, 96) 1536        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 128, 128, 96) 384         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 128, 128, 96) 0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 129, 129, 96) 0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 64, 64, 96)   864         block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 64, 64, 96)   384         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 64, 64, 96)   0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 64, 64, 24)   2304        block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 64, 64, 24)   96          block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 64, 64, 144)  3456        block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 64, 64, 144)  576         block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 64, 64, 144)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 64, 64, 24)   3456        block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 64, 64, 24)   96          block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 64, 64, 24)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 64, 64, 144)  3456        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 64, 64, 144)  576         block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 64, 64, 144)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 64, 64, 24)   3456        block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 64, 64, 24)   96          block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 64, 64, 24)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 64, 64, 144)  3456        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 64, 64, 144)  576         block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 64, 64, 144)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 64, 64, 24)   3456        block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 64, 64, 24)   96          block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 64, 64, 24)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 64, 64, 144)  3456        block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 64, 64, 144)  576         block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 64, 64, 144)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 64, 64, 144)  1296        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 64, 64, 144)  576         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 64, 64, 144)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 64, 64, 32)   4608        block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 64, 64, 32)   128         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 64, 64, 192)  6144        block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 64, 64, 192)  768         block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 64, 64, 192)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 64, 64, 192)  1728        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 64, 64, 192)  768         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 64, 64, 192)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 64, 64, 32)   6144        block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 64, 64, 32)   128         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 64, 64, 32)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 64, 64, 192)  6144        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 64, 64, 192)  768         block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 64, 64, 192)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 64, 64, 192)  1728        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 64, 64, 192)  768         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 64, 64, 192)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 64, 64, 32)   6144        block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 64, 64, 32)   128         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 64, 64, 32)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 64, 64, 192)  6144        block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 64, 64, 192)  768         block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 64, 64, 192)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 128, 128, 192 0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 288 0           up_sampling2d_12[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 64) 165952      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 128, 128, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 64) 36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 128, 64) 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 128, 64) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 256, 256, 64) 0           activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 256, 256, 112 0           up_sampling2d_13[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 48) 48432       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 48) 192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 256, 256, 48) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 256, 256, 48) 20784       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 48) 192         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 256, 256, 48) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 512, 512, 48) 0           activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 512, 512, 96) 0           up_sampling2d_14[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 512, 512, 32) 27680       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 512, 512, 32) 128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 512, 512, 32) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 512, 512, 32) 9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 512, 512, 32) 128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 512, 512, 32) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 1024, 1024, 3 0           activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 1024, 1024, 3 0           up_sampling2d_15[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1024, 1024, 1 5056        concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 1024, 1024, 1 64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 1024, 1024, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1024, 1024, 1 2320        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 1024, 1024, 1 64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 1024, 1024, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 1024, 1024, 1 17          activation_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 1024, 1024, 1 0           conv2d_35[0][0]
# ==================================================================================================
# Total params: 416,209
# Trainable params: 409,025
# Non-trainable params: 7,184
# __________________________________________________________________________________________________

# %% [markdown]
# ## Metrics

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# ## Training

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), Precision()]
model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 208/208 [==============================] - 75s 360ms/step - loss: 0.5815 - dice_coef: 0.4185 - recall_3: 0.7933 - precision_3: 0.4587 - val_loss: 0.8549 - val_dice_coef: 0.1451 - val_recall_3: 0.0248 - val_precision_3: 0.9139
# Epoch 2/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.4915 - dice_coef: 0.5085 - recall_3: 0.8438 - precision_3: 0.5380 - val_loss: 0.9106 - val_dice_coef: 0.0894 - val_recall_3: 7.7544e-06 - val_precision_3: 1.0000
# Epoch 3/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.4571 - dice_coef: 0.5429 - recall_3: 0.8388 - precision_3: 0.5722 - val_loss: 0.9256 - val_dice_coef: 0.0744 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00
# Epoch 4/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.4248 - dice_coef: 0.5752 - recall_3: 0.8357 - precision_3: 0.6040 - val_loss: 0.9363 - val_dice_coef: 0.0637 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00
# Epoch 5/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3933 - dice_coef: 0.6067 - recall_3: 0.8366 - precision_3: 0.6355 - val_loss: 0.9489 - val_dice_coef: 0.0511 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00
# Epoch 6/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3699 - dice_coef: 0.6301 - recall_3: 0.8464 - precision_3: 0.6639 - val_loss: 0.9355 - val_dice_coef: 0.0645 - val_recall_3: 3.5133e-04 - val_precision_3: 0.9477
# Epoch 7/50
# 208/208 [==============================] - 50s 241ms/step - loss: 0.3659 - dice_coef: 0.6341 - recall_3: 0.8478 - precision_3: 0.6685 - val_loss: 0.9241 - val_dice_coef: 0.0759 - val_recall_3: 0.0017 - val_precision_3: 0.9309
# Epoch 8/50
# 208/208 [==============================] - 50s 241ms/step - loss: 0.3624 - dice_coef: 0.6376 - recall_3: 0.8487 - precision_3: 0.6719 - val_loss: 0.9113 - val_dice_coef: 0.0887 - val_recall_3: 0.0043 - val_precision_3: 0.9166
# Epoch 9/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3590 - dice_coef: 0.6410 - recall_3: 0.8495 - precision_3: 0.6750 - val_loss: 0.8927 - val_dice_coef: 0.1073 - val_recall_3: 0.0120 - val_precision_3: 0.9133
# Epoch 10/50
# 208/208 [==============================] - 50s 239ms/step - loss: 0.3564 - dice_coef: 0.6436 - recall_3: 0.8497 - precision_3: 0.6792 - val_loss: 0.8432 - val_dice_coef: 0.1568 - val_recall_3: 0.0447 - val_precision_3: 0.8772
# Epoch 11/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3560 - dice_coef: 0.6440 - recall_3: 0.8507 - precision_3: 0.6787 - val_loss: 0.7710 - val_dice_coef: 0.2290 - val_recall_3: 0.1093 - val_precision_3: 0.8475
# Epoch 12/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3557 - dice_coef: 0.6443 - recall_3: 0.8511 - precision_3: 0.6788 - val_loss: 0.6783 - val_dice_coef: 0.3217 - val_recall_3: 0.2122 - val_precision_3: 0.8262
# Epoch 13/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3554 - dice_coef: 0.6446 - recall_3: 0.8512 - precision_3: 0.6790 - val_loss: 0.5887 - val_dice_coef: 0.4113 - val_recall_3: 0.3294 - val_precision_3: 0.8018
# Epoch 14/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3550 - dice_coef: 0.6450 - recall_3: 0.8513 - precision_3: 0.6793 - val_loss: 0.5185 - val_dice_coef: 0.4815 - val_recall_3: 0.4389 - val_precision_3: 0.7781
# Epoch 15/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3547 - dice_coef: 0.6453 - recall_3: 0.8514 - precision_3: 0.6796 - val_loss: 0.4699 - val_dice_coef: 0.5301 - val_recall_3: 0.5246 - val_precision_3: 0.7556
# Epoch 16/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3544 - dice_coef: 0.6456 - recall_3: 0.8515 - precision_3: 0.6798 - val_loss: 0.4381 - val_dice_coef: 0.5619 - val_recall_3: 0.5900 - val_precision_3: 0.7365
# Epoch 17/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3540 - dice_coef: 0.6460 - recall_3: 0.8515 - precision_3: 0.6801 - val_loss: 0.4176 - val_dice_coef: 0.5824 - val_recall_3: 0.6381 - val_precision_3: 0.7197
# Epoch 18/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3537 - dice_coef: 0.6463 - recall_3: 0.8516 - precision_3: 0.6804 - val_loss: 0.4042 - val_dice_coef: 0.5958 - val_recall_3: 0.6742 - val_precision_3: 0.7062
# Epoch 19/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3534 - dice_coef: 0.6466 - recall_3: 0.8516 - precision_3: 0.6807 - val_loss: 0.3951 - val_dice_coef: 0.6049 - val_recall_3: 0.7016 - val_precision_3: 0.6957
# Epoch 20/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3530 - dice_coef: 0.6470 - recall_3: 0.8517 - precision_3: 0.6810 - val_loss: 0.3889 - val_dice_coef: 0.6111 - val_recall_3: 0.7220 - val_precision_3: 0.6875
# Epoch 21/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3527 - dice_coef: 0.6473 - recall_3: 0.8517 - precision_3: 0.6812 - val_loss: 0.3846 - val_dice_coef: 0.6154 - val_recall_3: 0.7371 - val_precision_3: 0.6809
# Epoch 22/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3524 - dice_coef: 0.6476 - recall_3: 0.8518 - precision_3: 0.6815 - val_loss: 0.3816 - val_dice_coef: 0.6184 - val_recall_3: 0.7483 - val_precision_3: 0.6758
# Epoch 23/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3521 - dice_coef: 0.6479 - recall_3: 0.8518 - precision_3: 0.6818 - val_loss: 0.3795 - val_dice_coef: 0.6205 - val_recall_3: 0.7567 - val_precision_3: 0.6717
# Epoch 24/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3517 - dice_coef: 0.6483 - recall_3: 0.8519 - precision_3: 0.6820 - val_loss: 0.3779 - val_dice_coef: 0.6221 - val_recall_3: 0.7630 - val_precision_3: 0.6685
# Epoch 25/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3514 - dice_coef: 0.6486 - recall_3: 0.8519 - precision_3: 0.6823 - val_loss: 0.3768 - val_dice_coef: 0.6232 - val_recall_3: 0.7680 - val_precision_3: 0.6661
# Epoch 26/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3511 - dice_coef: 0.6489 - recall_3: 0.8520 - precision_3: 0.6826 - val_loss: 0.3759 - val_dice_coef: 0.6241 - val_recall_3: 0.7718 - val_precision_3: 0.6641
# Epoch 27/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3507 - dice_coef: 0.6493 - recall_3: 0.8520 - precision_3: 0.6829 - val_loss: 0.3752 - val_dice_coef: 0.6248 - val_recall_3: 0.7748 - val_precision_3: 0.6626
# Epoch 28/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3504 - dice_coef: 0.6496 - recall_3: 0.8520 - precision_3: 0.6831 - val_loss: 0.3746 - val_dice_coef: 0.6254 - val_recall_3: 0.7771 - val_precision_3: 0.6613
# Epoch 29/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3501 - dice_coef: 0.6499 - recall_3: 0.8521 - precision_3: 0.6834 - val_loss: 0.3741 - val_dice_coef: 0.6259 - val_recall_3: 0.7789 - val_precision_3: 0.6602
# Epoch 30/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3497 - dice_coef: 0.6503 - recall_3: 0.8521 - precision_3: 0.6837 - val_loss: 0.3738 - val_dice_coef: 0.6262 - val_recall_3: 0.7803 - val_precision_3: 0.6594
# Epoch 31/50
# 208/208 [==============================] - 50s 241ms/step - loss: 0.3494 - dice_coef: 0.6506 - recall_3: 0.8521 - precision_3: 0.6840 - val_loss: 0.3734 - val_dice_coef: 0.6266 - val_recall_3: 0.7814 - val_precision_3: 0.6588
# Epoch 32/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3490 - dice_coef: 0.6510 - recall_3: 0.8521 - precision_3: 0.6842 - val_loss: 0.3731 - val_dice_coef: 0.6269 - val_recall_3: 0.7822 - val_precision_3: 0.6583
# Epoch 33/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3486 - dice_coef: 0.6514 - recall_3: 0.8521 - precision_3: 0.6845 - val_loss: 0.3729 - val_dice_coef: 0.6271 - val_recall_3: 0.7828 - val_precision_3: 0.6580
# Epoch 34/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3482 - dice_coef: 0.6518 - recall_3: 0.8520 - precision_3: 0.6848 - val_loss: 0.3726 - val_dice_coef: 0.6274 - val_recall_3: 0.7831 - val_precision_3: 0.6578
# Epoch 35/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3477 - dice_coef: 0.6523 - recall_3: 0.8519 - precision_3: 0.6851 - val_loss: 0.3724 - val_dice_coef: 0.6276 - val_recall_3: 0.7832 - val_precision_3: 0.6577
# Epoch 36/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3472 - dice_coef: 0.6528 - recall_3: 0.8517 - precision_3: 0.6854 - val_loss: 0.3720 - val_dice_coef: 0.6280 - val_recall_3: 0.7831 - val_precision_3: 0.6578
# Epoch 37/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3465 - dice_coef: 0.6535 - recall_3: 0.8513 - precision_3: 0.6858 - val_loss: 0.3716 - val_dice_coef: 0.6284 - val_recall_3: 0.7828 - val_precision_3: 0.6580
# Epoch 38/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3457 - dice_coef: 0.6543 - recall_3: 0.8509 - precision_3: 0.6863 - val_loss: 0.3711 - val_dice_coef: 0.6289 - val_recall_3: 0.7824 - val_precision_3: 0.6583
# Epoch 39/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3448 - dice_coef: 0.6552 - recall_3: 0.8503 - precision_3: 0.6869 - val_loss: 0.3706 - val_dice_coef: 0.6294 - val_recall_3: 0.7817 - val_precision_3: 0.6588
# Epoch 40/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3439 - dice_coef: 0.6561 - recall_3: 0.8495 - precision_3: 0.6875 - val_loss: 0.3700 - val_dice_coef: 0.6300 - val_recall_3: 0.7809 - val_precision_3: 0.6592
# Epoch 41/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3429 - dice_coef: 0.6571 - recall_3: 0.8487 - precision_3: 0.6883 - val_loss: 0.3694 - val_dice_coef: 0.6306 - val_recall_3: 0.7801 - val_precision_3: 0.6598
# Epoch 42/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3419 - dice_coef: 0.6581 - recall_3: 0.8479 - precision_3: 0.6892 - val_loss: 0.3687 - val_dice_coef: 0.6313 - val_recall_3: 0.7793 - val_precision_3: 0.6603
# Epoch 43/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3410 - dice_coef: 0.6590 - recall_3: 0.8471 - precision_3: 0.6900 - val_loss: 0.3681 - val_dice_coef: 0.6319 - val_recall_3: 0.7786 - val_precision_3: 0.6607
# Epoch 44/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3401 - dice_coef: 0.6599 - recall_3: 0.8465 - precision_3: 0.6908 - val_loss: 0.3674 - val_dice_coef: 0.6326 - val_recall_3: 0.7781 - val_precision_3: 0.6611
# Epoch 45/50
# 208/208 [==============================] - 50s 239ms/step - loss: 0.3393 - dice_coef: 0.6607 - recall_3: 0.8460 - precision_3: 0.6915 - val_loss: 0.3669 - val_dice_coef: 0.6331 - val_recall_3: 0.7777 - val_precision_3: 0.6613
# Epoch 46/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3385 - dice_coef: 0.6615 - recall_3: 0.8456 - precision_3: 0.6921 - val_loss: 0.3663 - val_dice_coef: 0.6337 - val_recall_3: 0.7774 - val_precision_3: 0.6615
# Epoch 47/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3378 - dice_coef: 0.6622 - recall_3: 0.8452 - precision_3: 0.6927 - val_loss: 0.3658 - val_dice_coef: 0.6342 - val_recall_3: 0.7771 - val_precision_3: 0.6617
# Epoch 48/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3372 - dice_coef: 0.6628 - recall_3: 0.8450 - precision_3: 0.6932 - val_loss: 0.3654 - val_dice_coef: 0.6346 - val_recall_3: 0.7768 - val_precision_3: 0.6619
# Epoch 49/50
# 208/208 [==============================] - 50s 241ms/step - loss: 0.3367 - dice_coef: 0.6633 - recall_3: 0.8448 - precision_3: 0.6937 - val_loss: 0.3650 - val_dice_coef: 0.6350 - val_recall_3: 0.7765 - val_precision_3: 0.6621
# Epoch 50/50
# 208/208 [==============================] - 50s 240ms/step - loss: 0.3361 - dice_coef: 0.6639 - recall_3: 0.8446 - precision_3: 0.6942 - val_loss: 0.3647 - val_dice_coef: 0.6353 - val_recall_3: 0.7762 - val_precision_3: 0.6623

# %% [markdown]
# # Guardando modelo

# %%
model.save('Unet_MovileNetV2.h5')

# %% [markdown]
# ## Evaluation

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1

model.evaluate(test_dataset, steps=test_steps)
# Out:
# 25/25 [==============================] - 9s 342ms/step - loss: 0.3677 - dice_coef: 0.6323 - recall_3: 0.7570 - precision_3: 0.6835
# [0.36771777272224426,
#  0.6322823166847229,
#  0.7569820284843445,
#  0.6834580898284912]

# %% [markdown]
# ## Results

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:25], test_y[:25])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## How to Improve the Results

# %% [markdown]
# <ul>
#     <li> Use data augmentation </li>
#     <li> Use other pretrained encoder </li>
#     <li> Use a different decoder or different blocks in the decoder. </li>
#  </ul>

# %% [markdown]
# # Thank You
#
# FOLLOW US ON:
# <ul>
# <li><a href="https://www.youtube.com/idiotdeveloper"> YOUTUBE </a></li>
# <li><a href="https://facebook.com/idiotdeveloper"> FACEBOOK </a></li>
# <li><a href="https://twitter.com/nikhilroxtomar"> TWITTER </a></li>
# <li><a href="https://www.instagram.com/nikhilroxtomar"> INSTAGRAM </a></li>
# <li><a href="https://www.patreon.com/idiotdeveloper"> PATREON </a></li>
# </ul>
